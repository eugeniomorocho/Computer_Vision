# %% [markdown]
# # **Tutorial:** Real-time Object Detection with YOLO

# %% [markdown]
# In this tutorial, you will learn how to use the YOLOv11 model with OpenCV to automatically detect and draw bounding boxes around objects in an image.

# %% [markdown]
# ### **Step 1: Install Required Packages**

# %% [markdown]
# Install the necessary packages including OpenCV and other dependencies:

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
# %pip install numpy==1.26.4 --force-reinstall

# %% [markdown]
# Verify the installations:

# %%
# %pip show opencv-python ultralytics

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %% [markdown]
# Import the libraries you will use:

# %%
import numpy as np
import math
import cv2
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the YOLOv11 Model**

# %% [markdown]
# Load the pre-trained YOLOv11 model (automatically downloads if not available):

# %%
# Load a pretrained YOLO model version 11, nano (n) size
model = YOLO('yolo11n.pt')  # Using nano version for speed, other options: yolov11s.pt (small), yolov11m.pt (medium), yolov11l.pt (large), yolov11x.pt (extra large)

# %%
# Show class names the model can detect 
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### **Step 4.1: Run YOLO on your webcam video (the simple way)**

# %%
# Run YOLO model on your webcam
results = model.predict(
    source=0, # source=0 uses the default webcam, use source=1 for an external camera
    show=True, # show=True to display the video feed with detections in a window 
    stream=True, # stream=True for real-time processing of video frames
    imgsz=256, # resize frames to 256x256 for faster processing and lower resource usage
    vid_stride=3, # process every 3rd frame to reduce CPU/GPU load
    save=False # do not save the video output (this saves disk space and speeds up processing)
    #verbose=False # stops printing per-frame logs
    #conf=0.3, # confidence threshold of 30% (default is 0.25). Adjust as needed.
)

# %% [markdown]
# ### **Step 4.2: Run YOLO on your webcam video (the complete way)**

# %%
# Configure video capture from the camera
capture = cv2.VideoCapture(0)  # Open the default camera

# Define class names (YOLO COCO dataset classes)
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Set the image width and height
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Image width
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Image height

# Start a loop to process camera frames
while True:
    success, img = capture.read()  # Capture a frame

    # Perform object detection on the captured image (using the pre-trained YOLO model we loaded earlier)
    results = model(img, stream=True)  # Stream generator to process detection results in real time

    # Process the detection results (we can have multiple objects detected in a single frame)
    for r in results:
        boxes = r.boxes

        # Iterate over the detected bounding boxes
        for box in boxes:
            # Get the bounding box coordinates in xyxy format
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

            # Draw the bounding box on the image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Get the detection confidence (value between 0 and 1) and round to two decimal places
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)

            # Get the numeric identifier of the detected class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Display the class name next to the bounding box
            org = [x1, y1]  # Coordinates of the top-left corner for the text
            font = cv2.FONT_HERSHEY_SIMPLEX # Font type
            fontScale = 1  # Font scale
            color = (255, 0, 0)  # Color: Blue (BGR format)
            thickness = 1  # Text line thickness
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Display the image with a window name and the processed image with detections
    cv2.imshow('YOLO Detection', img)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 books, 262.2ms
# Confidence ---> 0.69
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 5.0ms preprocess, 262.2ms inference, 30.4ms postprocess per image at shape (1, 3, 480, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 480x640 1 suitcase, 3 books, 55.5ms
# Confidence ---> 0.43
# Class name --> suitcase
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 67.2ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 67.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 54.2ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 0.6ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 45.8ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 48.2ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 48.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 98.8ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.7ms preprocess, 98.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 52.1ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.8ms preprocess, 52.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 40.0ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 46.7ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 46.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 books, 46.3ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 46.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 42.8ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 39.7ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.6ms preprocess, 39.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 41.8ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 43.3ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 books, 45.0ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.9ms preprocess, 45.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 35.3ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.6ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 35.4ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 books, 35.5ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 35.4ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 34.2ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 34.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 35.2ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.5ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 35.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.5ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 35.4ms
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.5ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 books, 34.7ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 34.0ms
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.6ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 33.3ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 33.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 34.4ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 35.9ms
# Confidence ---> 0.66
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 34.8ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.8ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 37.2ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 36.0ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 36.2ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 33.4ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 33.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 34.0ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 34.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 34.4ms
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 35.6ms
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 35.6ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 39.3ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.7ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 38.0ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.7ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 40.2ms
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.5ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 39.2ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 39.2ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 39.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 39.0ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 38.8ms
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 38.5ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 38.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 books, 42.0ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 37.6ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 39.4ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 41.0ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 37.5ms
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 35.4ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.6ms preprocess, 35.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 35.2ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 33.2ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 36.9ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.6ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 37.4ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 37.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 books, 34.2ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 34.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 33.4ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 33.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 36.0ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 34.0ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 books, 33.6ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 33.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 books, 32.7ms
# Confidence ---> 0.67
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 32.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 36.0ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 35.8ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 35.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 35.0ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 33.4ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 33.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 34.2ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.6ms preprocess, 34.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 33.3ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 33.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 33.5ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 33.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 35.0ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 34.0ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 33.9ms
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 33.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 38.6ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 39.4ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 41.0ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 37.4ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.6ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 38.9ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 38.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 36.2ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.7ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 40.6ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 40.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 37.4ms
# Confidence ---> 0.65
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 35.5ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 34.8ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 35.5ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 34.3ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 34.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 34.3ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 36.6ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 36.8ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 35.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.6ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 34.3ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 34.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 35.4ms
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 1 clock, 36.3ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.29
# Class name --> clock
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 36.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 36.1ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 36.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 36.5ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 36.9ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 34.9ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 38.3ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 33.5ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.9ms preprocess, 33.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 33.5ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 33.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 33.1ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.6ms preprocess, 33.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 34.4ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 34.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 40.8ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 42.2ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 books, 42.7ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.6ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 1 clock, 38.3ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.31
# Class name --> clock
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 38.3ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.6ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 39.0ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 39.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 36.9ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 38.3ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 37.7ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 37.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 37.3ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 37.7ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 37.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 38.2ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 38.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 36.9ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.6ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 37.2ms
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.7ms preprocess, 37.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 books, 38.0ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.6ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 35.3ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.6ms preprocess, 35.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 35.8ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 35.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 35.0ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 34.3ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 34.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 books, 39.0ms
# Confidence ---> 0.49
# Class name --> book
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.6ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 37.1ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 36.2ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.7ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 36.2ms
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 40.9ms
# Confidence ---> 0.62
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.6ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 35.1ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 35.0ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 35.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 books, 34.9ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 38.0ms
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 38.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 39.3ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 39.3ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 37.2ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 41.5ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 35.2ms
# ...
# Class name --> book
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 38.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.7ms preprocess, 38.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 38.4ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 38.3ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 39.8ms
# Confidence ---> 0.63
# Class name --> book
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.8ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 39.7ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 38.8ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 38.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 36.2ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.7ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 35.1ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 39.7ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 34.6ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 34.3ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 34.1ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 38.9ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 33.7ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.6ms preprocess, 33.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 36.0ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 35.0ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.6ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 37.6ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.0ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 32.6ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.5ms preprocess, 32.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 books, 35.0ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 33.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 3 books, 37.3ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.6ms preprocess, 37.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 books, 33.6ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 33.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 4 books, 37.0ms
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.7ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 63.7ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.0ms preprocess, 63.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 34.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.8ms preprocess, 34.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 95.4ms
# Confidence ---> 0.49
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 95.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 1 clock, 46.4ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> clock
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 46.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 40.4ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 37.0ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 37.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 4 books, 37.6ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 38.2ms
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.7ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 37.0ms
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 37.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 35.9ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 4 books, 51.8ms
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.6ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 58.5ms
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.5ms preprocess, 58.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 38.6ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 38.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 63.8ms
# Confidence ---> 0.61
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 70.5ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.9ms preprocess, 70.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 38.3ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 books, 35.9ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 books, 42.4ms
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 3 books, 34.9ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.6ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 35.8ms
# Confidence ---> 0.59
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.1: Run YOLO on an Image (the simple way)**

# %%
# Run yolo model on an image
results = model.predict(source="/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg", show=True)
# Out:
# image 1/1 /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg: 640x640 1 cat, 270.4ms
# Speed: 4.4ms preprocess, 270.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.2: Run YOLO on an Image (the complete way)**

# %% [markdown]
# Load your image and prepare it for inference:

# %%
# Load an image (change the path to your image file)
image_bgr = cv2.imread('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg')

# %% [markdown]
# Run inference

# %%
# Run inference
results = model(image_bgr)
# Out:
# 0: 640x640 1 cat, 194.7ms
# Speed: 35.0ms preprocess, 194.7ms inference, 14.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Extract detection results
boxes = results[0].boxes  # Bounding boxes
scores = boxes.conf       # Confidence scores
class_ids = boxes.cls     # Class IDs

# Create a copy of the original image to draw on
image_with_boxes = image_bgr.copy()

# Define colors for different classes
colors = [(0, 255, 0), (0, 0, 255), (255, 0, 0), (255, 255, 0), 
          (0, 255, 255), (255, 0, 255), (255, 165, 0), (128, 0, 128)]

# Draw bounding boxes and labels for each detection
for i, (box, score, class_id) in enumerate(zip(boxes.xyxy, scores, class_ids)):
    # Convert tensor to numpy array
    x1, y1, x2, y2 = box.cpu().numpy()
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    
    # Get class name and color
    class_name = model.names[class_id]
    color = colors[class_id % len(colors)]
    
    # Draw bounding box
    cv2.rectangle(image_with_boxes, (int(x1), int(y1)), (int(x2), int(y2)), color, 5)
    
    # Create label text
    label = f"{class_name}: {score:.2f}"
    
    # Calculate text position
    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
    label_y = max(int(y1) - 10, label_size[1] + 10)
    
    # Draw text background
    cv2.rectangle(image_with_boxes, 
                 (int(x1), label_y - label_size[1] - 10),
                 (int(x1) + label_size[0], label_y + 5),
                 color, -1)
    
    # Draw text
    cv2.putText(image_with_boxes, label, 
               (int(x1), label_y - 5), 
               cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
# Convert from BGR to RGB for matplotlib
image_with_boxes_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the result
plt.figure(figsize=(12, 10))
plt.imshow(image_with_boxes_rgb)
plt.title('Object Detection with YOLOv11')
plt.axis('off')
plt.show()

# Print detection summary
print(f"Detected {len(boxes)} objects:")
for i, (class_id, score) in enumerate(zip(class_ids, scores)):
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    print(f"  {i+1}. {model.names[class_id]} (confidence: {score:.2f})")

# %% [markdown]
# ### **Step 6.1: Run Object Detection on a saved video (the simple way)**

# %% [markdown]
# Inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos.

# %%
# YOLO on a saved video
results = model.predict(source='/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/car-detection.mp4', show=True, stream=True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 6.2: Run Object Detection on a saved video (the complete way)**

# %%
# Load YOLO model
model = YOLO('yolov8n.pt')

# Configure your video path
video_path = "/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/race_car.mp4"

# Open video
cap = cv2.VideoCapture(video_path)

# Verify video opened correctly
if not cap.isOpened():
    print("Error: Could not open video. Check the path.")
else:
    print("Video loaded successfully. Press 'q' to exit.")
    
    # Process each video frame
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break  # Finish when video ends
            
        # Run detection with YOLO
        results = model(frame)
        
        # Draw bounding boxes
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
                confidence = float(box.conf[0].cpu().numpy())
                class_id = int(box.cls[0].cpu().numpy())
                
                # Only show detections with confidence > 50%
                if confidence > 0.5:
                    # Draw rectangle
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Show label
                    label = f"{model.names[class_id]}: {confidence:.2f}"
                    cv2.putText(frame, label, (x1, y1-10), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Show frame with detections
        cv2.imshow('Object Detection', frame)
        
        # Exit with 'q' key
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Processing completed.")
# Out:
# Video loaded successfully. Press 'q' to exit.
#
# 0: 416x640 2 cars, 182.5ms
# Speed: 5.0ms preprocess, 182.5ms inference, 5.6ms postprocess per image at shape (1, 3, 416, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 416x640 2 cars, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.2ms
# Speed: 1.3ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 62.5ms
# Speed: 1.1ms preprocess, 62.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 47.1ms
# Speed: 1.8ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.9ms
# Speed: 1.2ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.9ms
# Speed: 1.3ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.1ms
# Speed: 1.7ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.9ms
# Speed: 7.9ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.9ms
# Speed: 1.2ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.2ms
# Speed: 1.1ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.9ms
# Speed: 1.1ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.0ms
# Speed: 0.9ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.1ms
# Speed: 1.2ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.1ms
# Speed: 1.1ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.8ms
# Speed: 1.1ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.6ms
# Speed: 1.0ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.8ms
# Speed: 1.0ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.9ms
# Speed: 0.9ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 39.8ms
# Speed: 1.1ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.8ms
# Speed: 1.1ms preprocess, 34.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.2ms
# Speed: 9.1ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.7ms
# Speed: 0.9ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.9ms
# Speed: 0.9ms preprocess, 35.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 38.1ms
# Speed: 1.2ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 39.3ms
# Speed: 1.3ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 persons, 2 cars, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 3 cars, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.3ms
# Speed: 1.1ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.6ms
# Speed: 1.0ms preprocess, 31.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 30.8ms
# Speed: 0.9ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 30.8ms
# Speed: 0.9ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.7ms
# Speed: 0.9ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.0ms
# Speed: 1.2ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.8ms
# Speed: 0.9ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.4ms
# Speed: 1.0ms preprocess, 31.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.6ms
# Speed: 6.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.5ms
# Speed: 3.0ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.4ms
# Speed: 6.2ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 0.9ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 0.9ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.5ms
# Speed: 0.9ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 0.9ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 0.9ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.6ms
# Speed: 1.8ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 38.1ms
# Speed: 1.7ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.2ms
# Speed: 0.9ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.3ms
# Speed: 1.0ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 36.5ms
# Speed: 1.4ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.7ms
# Speed: 1.2ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.5ms
# Speed: 1.1ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.3ms
# Speed: 0.9ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.8ms
# Speed: 1.3ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 79.0ms
# Speed: 1.0ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 motorcycle, 35.1ms
# Speed: 1.1ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.8ms
# Speed: 1.1ms preprocess, 33.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.3ms
# Speed: 1.2ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.9ms
# Speed: 0.9ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
# Processing completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## **Activity**
#
# ### **Option 1: Mathematics Track**
#
# Clone your repository from GitHub and run the system directly on the Jetson Nano.
#
# #### Access to the Jetson Nano
#
# You will be provided with:
# - Username
# - Jetson Nano IP address
# - Password
#
# Use your computer's terminal to connect:
#
# `ssh username@jetson_ip`
#
# #### 1. Clone the repository
# `git clone https://github.com/user/repository.git`
#
# #### 2. Access the project directory
# `cd repository`
#
# #### 3. Create virtual environment and install dependencies
# `python3 -m venv env`
# `source env/bin/activate`
# `pip install -r requirements.txt`
#
# #### 4. Run the virtual environment
# `python YOLO-Real-Time.py`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. SSH Connection** | 2 | Successfully establishes SSH connection to Jetson Nano. Properly handles authentication and connection setup. |
# | **2. Environment Setup** | 3 | Creates virtual environment and installs all dependencies correctly. Resolves any platform-specific issues. |
# | **3. Application Execution** | 3 | Runs YOLO real-time detection successfully on Jetson Nano. Handles hardware acceleration properly. |
# | **4. Performance Optimization** | 2 | Implements optimizations for Jetson Nano hardware. Maintains acceptable frame rate for real-time detection. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 2: Computer Science Track**
#
# Create a Dockerfile in your Jetson Nano folder:
#
# #### Dockerfile
#
# `FROM nvcr.io/nvidia/l4t-pytorch:r32.7.1-pth1.11-py3`
# `RUN apt-get update && apt-get install -y python3-pip libopencv-dev`
# `RUN pip3 install ultralytics opencv-python`
#
# `COPY . /app`
# `WORKDIR /app`
#
# `CMD ["python3", "YOLO-Real-Time.py"]`
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### Steps to build and run:
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Repository Setup** | 2 | Successfully clones repository and sets up environment. All dependencies installed correctly without errors. |
# | **2. Docker Implementation** | 3 | Dockerfile is properly configured with all necessary dependencies. Image builds successfully without errors. |
# | **3. Container Execution** | 3 | Container runs successfully with camera access. Real-time detection works properly in Docker environment. |
# | **4. System Performance** | 2 | Application runs smoothly with acceptable frame rate. Handles video streaming without crashes or major issues. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 3: Master's in Artificial Intelligence / Data Science**
#
# In this option, the work will be developed **locally on your personal computers**.
#
# #### Objective
# Design a **specific object detection application** using YOLO (You Only Look Once), focused on **a limited subset of classes**. The system must show that **it only detects the activated classes**, visually ignoring objects belonging to deactivated classes (even if they are present in the image).
#
# #### Instructions
#
# 1. **Define a concrete application and the problem it solves**, for example: vehicle detection, fruits detection, etc.
# 2. **Select between 2 and 4 classes** from the YOLOv8 model to detect.
# 3. **Modify the model logic** or post-processing so that **only the selected classes are shown**.
# 4. Run the application on video where **objects from non-activated classes** are also present to demonstrate that the system **ignores those classes**.
# 5. Show the results clearly, visually indicating the detected and non-detected objects.
#
# #### Technical Requirements
#
# - Use `ultralytics` with `YOLO` in any version.
# - You can use your webcam video or local video (no static images allowed).
#
# #### Deliverable
#
# Must be uploaded to the virtual classroom:
#
# - **Jupyter Notebook in PDF format** containing:
# - Commented code
# - Application title and the problem it solves
# - List of activated classes
# - Screenshots or test images with results showing:
#   - Objects *correctly detected* according to the activated classes.
#   - Objects *not detected* because they belong to deactivated classes (even if present in the image).
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Application Definition and Problem Statement** | 1 | Clearly defines a specific object detection application and its practical use case. Selects appropriate classes for the application context. |
# | **2. Class Selection and Justification** | 1 | Selects between 2-4 relevant classes from YOLOv8 model. Demonstrates thoughtful choice of classes for the specific application. |
# | **3. Implementation** | 4 | Successfully modifies the model logic or post-processing to only show selected classes. Code is functional and properly ignores non-selected classes. |
# | **4. Testing & Evidence** | 3 | Provides a clear test showing both detected (activated classes) and ignored (deactivated classes) objects. Evidence demonstrates the filtering works correctly. |
# | **5. Documentation** | 1 | Delivers complete documentation including PDF notebook, application title, class list, and proper screenshots. Submission is well-organized and professional. |
#
# Total: 10 points

# %%
# Write your code here..

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
